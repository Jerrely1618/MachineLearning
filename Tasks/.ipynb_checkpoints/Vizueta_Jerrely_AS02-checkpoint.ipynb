# %% [markdown]
# # Iris dataset

# %% [markdown]
# ### Import modules

# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits import mplot3d
from sklearn import datasets
from sklearn.linear_model import SGDClassifier
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Loading data

# %%
data = datasets.load_iris()
feature_values = data.data
labels = data.target
classes = data.target_names
features = data.feature_names

sestosas, versicolors, virginicas = np.array([feature_values[0]]),np.array([feature_values[0]]),np.array([feature_values[0]])
for i in range(len(labels)):
    iris_values = feature_values[i]
    if labels[i] == 0: 
        sestosas = np.append(sestosas,[iris_values],axis=0)
    elif labels[i] == 1:
        versicolors = np.append(versicolors,[iris_values],axis=0)
    else:
        virginicas = np.append(virginicas,[iris_values],axis=0)

sestosas = sestosas[1:]
versicolors = versicolors[1:]
virginicas = virginicas[1:]

# %%
print(f"Classes: >{classes[0]} >{classes[1]} >{classes[2]}")
print(f"Features: >{features[0]} >{features[1]} >{features[2]} >{features[3]}")
# Out:
# Classes: >setosa >versicolor >virginica
# Features: >sepal length (cm) >sepal width (cm) >petal length (cm) >petal width (cm)

# %% [markdown]
# ### Feature Combinations

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(12,12))

k,k1,k2 = 0,0,0
for i in range(4):
    for j in range(i+1,4):
        k1,k2 = int(k/2),np.mod(k,2) 
        ax[k1,k2].scatter(sestosas[:,i],sestosas[:,j], label = "Versicolor")
        ax[k1,k2].scatter(versicolors[:,i],versicolors[:,j], label = "Sestosa", marker = "x")
        ax[k1,k2].scatter(virginicas[:,i],virginicas[:,j], label = "Virginicas", marker="*")
        ax[k1,k2].legend(loc="lower right", fontsize='x-small')
        ax[k1,k2].set_xlim(0,10)
        ax[k1,k2].set_xlabel(f"{features[i].capitalize()}")
        ax[k1,k2].set_ylabel(f"{features[j].capitalize()}")
        k += 1
plt.show()

# %%
k,k1,k2 = 0,0,0
for i in range(4):
    for j in range(i+1,4):
        for p in range(j+1,4):
            fig = plt.figure(figsize=(3,3))
            ax = plt.axes(projection='3d')
            ax.scatter3D(sestosas[:,i],sestosas[:,j],sestosas[:,p], label = "Versicolor")
            ax.scatter3D(versicolors[:,i],versicolors[:,j],versicolors[:,p], label = "Sestosa", marker = "x")
            ax.scatter3D(virginicas[:,i],virginicas[:,j],virginicas[:,p], label = "Virginicas", marker = "*")
            
            ax.legend(loc="lower right", fontsize='x-small')
            ax.set_xlim(0,10)
            ax.set_ylim(0,10)
            ax.set_xlabel(f"{features[i].capitalize()}")
            ax.set_ylabel(f"{features[j].capitalize()}")
            ax.set_zlabel(f"{features[k].capitalize()}")
            k += 1
plt.show()

# %% [markdown]
# ### A(Sepal Length)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.61
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            26
#
# Intercept_       [-305.23733681]
# Coef_            [[63.62878577]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            20
#
# Intercept_       [-305.33857845]
# Coef_            [[38.67955985]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            58
#
# Intercept_       [2.36393124e+13]
# Coef_            [[-1.32499767e+13]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.85
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            35
#
# Intercept_       [-1244.12936499]
# Coef_            [[233.19389445]]

# %% [markdown]
# ### B (Sepal Width)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[0,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.81
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            17
#
# Intercept_       [168.43259961]
# Coef_            [[-52.61207855]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[0,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.82
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            39
#
# Intercept_       [170.99626905]
# Coef_            [[-57.97101449]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[0,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            166
#
# Intercept_       [-2.00780397e+12]
# Coef_            [[-9.07709875e+11]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[0,2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.81
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     1
# n_iter_            10
#
# Intercept_       [621.30334713]
# Coef_            [[-191.19184055]]

# %% [markdown]
# ### AB (Sepal Length and Sepal Width)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.99
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            8
#
# Intercept_       [-38.8101943]
# Coef_            [[ 130.62812674 -212.89605336]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.99
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            8
#
# Intercept_       [-38.80560103]
# Coef_            [[ 133.40744858 -217.34296832]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            116
#
# Intercept_       [8.26022072e+12]
# Coef_            [[-8.00251934e+10  2.70884078e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[2,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.99
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            8
#
# Intercept_       [-135.83943245]
# Coef_            [[ 482.49027237 -777.09838799]]

# %% [markdown]
# ### AC (Sepal Length and Petal Length)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            7
#
# Intercept_       [-19.18973919]
# Coef_            [[-29.42907593  64.15538552]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            7
#
# Intercept_       [-19.18973919]
# Coef_            [[-29.42907593  64.15538552]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,3],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            65
#
# Intercept_       [-2.09918088e+12]
# Coef_            [[ 2.77157383e+11 -2.34064694e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,3],axis=1)
A = clf.fit(XX,YY)
                   
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            7
#
# Intercept_       [-58.83209219]
# Coef_            [[-110.65332549  236.60977045]]

# %% [markdown]
# ### AD (Sepal Length and Petal Length)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            8
#
# Intercept_       [-27.1558268]
# Coef_            [[-6.67037243 73.92996109]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            8
#
# Intercept_       [-18.76013404]
# Coef_            [[-7.2262368  73.92996109]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            80
#
# Intercept_       [1.42449615e+13]
# Coef_            [[9.88888733e+11 2.04739694e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,[1,2],axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     2
# n_iter_            7
#
# Intercept_       [-87.47301802]
# Coef_            [[-25.89758682 273.1018246 ]]

# %% [markdown]
# ## ABC (Sepal Length and Sepal Width and Petal Length)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,3,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            7
#
# Intercept_       [-9.90248841]
# Coef_            [[ -7.65155974 -34.13772808  55.32666274]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,3,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            7
#
# Intercept_       [-9.90248841]
# Coef_            [[ -7.65155974 -34.13772808  55.32666274]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,3,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            115
#
# Intercept_       [5.29748107e+12]
# Coef_            [[-4.14254365e+12 -6.19086691e+12  4.45775364e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,3,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            7
#
# Intercept_       [-19.84276262]
# Coef_            [[-16.48028252 -60.03531489 121.24779282]]

# %% [markdown]
# ### ABD (Sepal Length and Sepal Width and Petal Width)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,2,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            7
#
# Intercept_       [-9.72494371]
# Coef_            [[ 26.48616833 -71.80694526  69.45261919]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,2,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)

print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            7
#
# Intercept_       [-9.72494371]
# Coef_            [[ 26.48616833 -71.80694526  69.45261919]]

# %% [markdown]
# #### Least-squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,2,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            106
#
# Intercept_       [8.08715535e+12]
# Coef_            [[-1.24913556e+12 -1.76656704e+12 -1.73499684e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
XX = np.delete(XX,2,axis=1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     3
# n_iter_            8
#
# Intercept_       [-50.45201464]
# Coef_            [[ 131.77980839 -351.63632565  372.96414678]]

# %% [markdown]
# ### ABCD (Sepal Length and Sepal Width and Petal Length and Petal Width)

# %% [markdown]
# #### Perceptron

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='perceptron')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     4
# n_iter_            7
#
# Intercept_       [-9.90300848]
# Coef_            [[-11.77163037 -32.37198352  49.44084756  24.72042378]]

# %% [markdown]
# #### Hinge

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='hinge')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     4
# n_iter_            7
#
# Intercept_       [-9.90300848]
# Coef_            [[-11.77163037 -32.37198352  49.44084756  24.72042378]]

# %% [markdown]
# #### Least-Squares

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='squared_error')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  0.5
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     4
# n_iter_            176
#
# Intercept_       [1.10572094e+13]
# Coef_            [[-2.40629519e+11 -5.37237433e+12 -1.14632002e+12 -1.81810587e+12]]

# %% [markdown]
# #### Modified Huber

# %%
clf = SGDClassifier(tol=1e-4,random_state=0,loss='modified_huber')
XX = np.append(sestosas,versicolors,axis=0)
row,col = sestosas.shape
row1,col1 = versicolors.shape
YY = np.zeros(row)

for i in range(row1):
    YY = np.append(YY,1)
A = clf.fit(XX,YY)
print('\nScore: ',clf.score(XX,YY))
print ('\nnumber of classes ',len(A.classes_))
print ('classes_          ',A.classes_)
print ('n_features_in_    ',A.n_features_in_)
print ('n_iter_           ',A.n_iter_ )
print ('\nIntercept_      ',A.intercept_)
print ('Coef_           ',A.coef_)
# Out:
# Score:  1.0
#
# number of classes  2
# classes_           [0. 1.]
# n_features_in_     4
# n_iter_            7
#
# Intercept_       [-19.84276262]
# Coef_            [[-16.48028252 -60.03531489 121.24779282  51.79517363]]
